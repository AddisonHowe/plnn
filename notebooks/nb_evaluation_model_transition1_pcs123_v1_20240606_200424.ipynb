# %% [markdown]
# # Trained Model Evaluation Notebook

# %%
import tqdm.notebook as tqdm
import numpy as np
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import jax.random as jrandom
import equinox as eqx
from IPython.display import HTML

from plnn.models import DeepPhiPLNN
from plnn.dataset import get_dataloaders
from plnn.data_generation.plnn_animator import PLNNSimulationAnimator
from plnn.io import load_model_from_directory, load_model_training_metadata
from plnn.loss_functions import kl_divergence_loss

SEED = None
rng = np.random.default_rng(seed=SEED)

# %% [markdown]
# ### Model Loading

# %%
BASEDIR = "../data/trained_models"
MODEL_DIR = "model_transition1_pcs123_v1_20240606_200424"
MODEL_NAME = "model_transition1_pcs123_v1"

DATDIR = "../data/training_data/data_transition1_subset_epi_trans_ce_an_pc123"

INDEX = 'best'
modeldir = f"../data/trained_models/{MODEL_DIR}"

# %%
datdir_train = f"{DATDIR}/training"
datdir_valid = f"{DATDIR}/validation"
datdir_test = f"{DATDIR}/validation"  # NOTE: No test data

nsims_train = np.genfromtxt(f"{datdir_train}/nsims.txt", dtype=int)
nsims_valid = np.genfromtxt(f"{datdir_valid}/nsims.txt", dtype=int)
nsims_test = np.genfromtxt(f"{datdir_test}/nsims.txt", dtype=int)

# %%
# Load the model
model, hyperparams, idx, model_name, model_fpath = load_model_from_directory(
    modeldir, 
    subdir="states",
    idx=INDEX,
    model_class=DeepPhiPLNN,
    dtype=jnp.float64,
)

# Load the argument dictionary and training run dictionary
logged_args, run_dict = load_model_training_metadata(
    modeldir
)

loss_train = run_dict['loss_hist_train']
loss_valid = run_dict['loss_hist_valid']
sigma_hist = run_dict['sigma_hist']
lr_hist = run_dict['learning_rate_hist']

print(f"Loading model `{model_name}` at epoch {idx} from file: {model_fpath}.")
# Out:
# Loading model `model_transition1_pcs123_v1` at epoch 1160 from file: ../data/trained_models/model_transition1_pcs123_v1_20240606_200424/states/model_transition1_pcs123_v1_1160.pth.

# %% [markdown]
# ### Training process metadata
# Before examining the inferred landscape, let's look at the training process metadata.

# %%
from plnn.pl import plot_training_loss_history, plot_validation_loss_history, \
    plot_loss_history, plot_sigma_history, plot_learning_rate_history

# %%
logplot = True
loss_method = logged_args['loss']
optimizer = logged_args['optimizer']

fig, axes = plt.subplots(3, 2, figsize=(12,8))

plot_loss_history(
    loss_train, loss_valid,
    log=logplot, 
    title=f"Loss History ({loss_method}, {optimizer})",
    ax=axes[0, 0],
)

plot_learning_rate_history(
    lr_hist, log=False,
    ax=axes[1, 0],
)

plot_sigma_history(
    sigma_hist, log=False,
    ax=axes[2, 0],
)

plot_training_loss_history(
    loss_train, 
    log=logplot, 
    title=f"Training Loss ({loss_method}, {optimizer})",
    ax=axes[0, 1],
    color='r', marker='.', linestyle='none',
)

plot_validation_loss_history(
    loss_valid, 
    log=logplot, 
    title=f"Validation Loss ({loss_method}, {optimizer})",
    ax=axes[1, 1],
    color='b',
)

plt.tight_layout()

# %% [markdown]
# ### Variance in loss
# Let's examine the noisyness of the training and validation loss in the plots above.

# %%
key = jrandom.PRNGKey(rng.integers(2**32))

# %%
k = 100
var_train_loss = np.var(loss_train[-k:])
var_valid_loss = np.var(loss_valid[-k:])
print(f"Training loss variance (last {k} epochs)  : {var_train_loss}")
print(f"Validation loss variance (last {k} epochs): {var_valid_loss}")
# Out:
# Training loss variance (last 100 epochs)  : 1.5028006715119138e-05
# Validation loss variance (last 100 epochs): 1.8528959994031036e-05

# %%
nepochs = len(loss_train)
start_epoch = 0
k = 10
vtls = []
vvls = []
ranges = []
for i in range((nepochs - start_epoch) // k):
    n0, n1 = start_epoch + k*i, start_epoch + k*(i+1)
    tset = loss_train[n0:n1]
    vset = loss_valid[n0:n1]
    var_train_loss = np.var(tset)
    var_valid_loss = np.var(vset)
    vtls.append(var_train_loss)
    vvls.append(var_valid_loss)
    ranges.append(str(n0) + '-' + str(n1))

fig, ax = plt.subplots(1, 1)
ax.plot(vtls, label="Training")
ax.plot(vvls, label="Validation")
ax.set_xlabel("Epochs")
ax.set_ylabel("Avg loss variance")
ax.legend()
ax.set_xticks(range(len(ranges)), ranges, rotation=45);

# %%
_, _, test_loader, _, _, test_dset = get_dataloaders(
    datdir_train, datdir_valid, nsims_train, nsims_valid,
    return_datasets=True,
    include_test_data=True,
    datdir_test=datdir_test, nsims_test=nsims_test, shuffle_test=True,
    batch_size_test=5,
    ncells_sample=model.ncells,
)

# %%
@eqx.filter_jit
def compute_loss(model, x, y, loss_fn, key):
    t0, y0, t1, sigparams = x
    y_pred = model(t0, t1, y0, sigparams, key)
    return loss_fn(y_pred, y), y_pred

# %%
ntrials = 10

avg_test_losses = np.zeros(ntrials)
pbar = tqdm.tqdm(total=len(test_loader))
for i in range(ntrials):
    test_losses = np.zeros(len(test_loader))
    pbar.set_description(f"i={i}/{ntrials}")
    for j, d in enumerate(test_loader):
        x, y = d
        key, subkey = jrandom.split(key, 2)
        loss, _ = compute_loss(model, x, y, kl_divergence_loss, subkey)
        test_losses[j] = loss
        pbar.update()
    avg_test_losses[i] = np.sum(test_losses) / len(test_loader)
    pbar.refresh()
    pbar.reset()
pbar.close()

print(np.var(avg_test_losses))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ## Comparison of true and inferred ensemble trajectories

# %%
_, _, test_loader, _, _, test_dset = get_dataloaders(
    datdir_train, datdir_valid, nsims_train, nsims_valid,
    return_datasets=True,
    include_test_data=True,
    datdir_test=datdir_test, nsims_test=nsims_test, shuffle_test=True,
    batch_size_test=1,
    ncells_sample=model.ncells,
)

# %%
key = jrandom.PRNGKey(123)

nsamps = 4
test_indices = [4, 5, 6, 7]

losses = np.zeros(nsamps)
x1obs_samples = []
x1sim_samples = []
iterloader = iter(test_loader)
for i in range(nsamps):
    inputs, x1obs = next(iterloader)
    inputs, x1obs = test_dset[test_indices[i]]
    t0, x0, t1, sigparams = inputs
    inputs = (jnp.array([v], dtype=jnp.float64) for v in inputs)
    x1obs = jnp.array([x1obs])
    key, subkey = jrandom.split(key, 2)
    model
    loss, x1sim = compute_loss(model, inputs, x1obs, kl_divergence_loss, subkey)
    losses[i] = loss
    x1obs_samples.append(x1obs[0])
    x1sim_samples.append(x1sim[0])

# %%
fig, axes = plt.subplots(2, 2, figsize=(6,6))

for i in range(len(losses)):
    ax = axes.flatten()[i]
    ax.plot(
        x1obs_samples[i][:,0], x1obs_samples[i][:,1], 
        color='k', marker='.', linestyle='none',
        label="obs"
    )
    ax.plot(
        x1sim_samples[i][:,0], x1sim_samples[i][:,1], 
        color='r', marker='.', linestyle='none',
        label="sim",
        alpha=0.9
    )
    ax.legend()
    ax.set_xlabel("$x$")
    ax.set_ylabel("$y$")
    ax.set_title(f"Loss: {losses[i]:.4g}")

plt.tight_layout()

# %%
model.get_parameters()['tilt.w']
# Out:
# [Array([[ 5.81706643,  1.60798007],
#         [-1.94994079, -2.6401549 ],
#         [-2.07463315,  0.22311495]], dtype=float64)]

# %%
model.plot_phi(
    signal=[1, 1.0],
    r=6,
    show=True,
);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 model.plot_phi(
#       2     signal=[1, 1.0],
#       3     r=6,
#       4     show=True,
#       5 );
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/Projects/plnn/plnn/models/plnn.py:1403, in PLNN.plot_phi(self, tilt, signal, sigparams, eval_time, r, res, plot3d, **kwargs)
#    1364 def plot_phi(
#    1365         self,
#    1366         tilt=None,
#    (...)
#    1373         **kwargs
#    1374 ):
#    1375     """Plot the scalar function phi.
#    1376
#    1377     Args:
#    (...)
#    1401         Axis object.
#    1402     """
# -> 1403     return pl.plot_phi(
#    1404         self,
#    1405         tilt=tilt,
#    1406         signal=signal,
#    1407         sigparams=sigparams,
#    1408         eval_time=eval_time,
#    1409         r=r,
#    1410         res=res,
#    1411         plot3d=plot3d,
#    1412         **kwargs
#    1413     )
#
# File ~/Documents/Projects/plnn/plnn/pl/plot_plnn.py:84, in plot_phi(model, tilt, signal, sigparams, eval_time, r, res, plot3d, lognormalize, normalize, minimum, clip, xlims, ylims, zlims, xlabel, ylabel, zlabel, xticks, yticks, zticks, title, title_fontsize, include_cbar, cbar_title, cbar_titlefontsize, cbar_ticklabelsize, cmap, ncontours, contour_linewidth, contour_linestyle, contour_linecolor, contour_linealpha, figsize, view_init, alpha, ax, equal_axes, tight_layout, saveas, show)
#      81     phi = model.phi_with_tilts(eval_time, z, jnp.array(tilt))
#      82 elif signal is not None:
#      83     # Signal values given directly
# ---> 84     phi = model.phi_with_signal(eval_time, z, jnp.array(signal))
#      85 elif (sigparams is not None) and (eval_time is not None):
#      86     # Signal parameters and evaluation time given.
#      87     phi = model.tilted_phi(eval_time, z, jnp.array(sigparams))
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/Projects/plnn/plnn/models/plnn.py:916, in PLNN.phi_with_signal(self, t, y, signal)
#     899 def phi_with_signal(
#     900         self,
#     901         t: Float,
#     902         y: Float[Array, "ncells ndims"],
#     903         signal: Float[Array, "nsigs"]
#     904 ) -> Float[Array, "ncells"]:
#     905     """Convenience function. Landscape level with tilt based on signal.
#     906
#     907     Vectorized across a number of particles. TODO: Test.
#    (...)
#     914         Array of shape (n,1).
#     915     """
# --> 916     return jax.vmap(self.eval_phi_with_signal, (None, 0, None))(t, y, signal)
#
#     [... skipping hidden 4 frame]
#
# File ~/Documents/Projects/plnn/plnn/models/plnn.py:876, in PLNN.eval_phi_with_signal(self, t, y, signal)
#     859 def eval_phi_with_signal(
#     860         self,
#     861         t: Float,
#     862         y: Float[Array, "ndims"],
#     863         signal: Float[Array, "nsigs"]
#     864 ) -> Float:
#     865     """Convenience function. Landscape level with tilt based on signal.
#     866
#     867     Acts on individual particle. TODO: Test.
#    (...)
#     874         Array of shape (1,).
#     875     """
# --> 876     phi = self.eval_phi(y)
#     877     tau = self.tilt_module(signal)
#     878     return phi + jnp.dot(tau, y)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/Projects/plnn/plnn/models/plnn_deep.py:130, in DeepPhiPLNN.eval_phi(self, y)
#     119 def eval_phi(
#     120     self,
#     121     y: Float[Array, "ndims"]
#     122 ) -> Float:
#     123     """Evaluate potential value without tilt.
#     124
#     125     Args:
#    (...)
#     128         Array of shape (1,).
#     129     """
# --> 130     return self.eval_confinement(y) + self.phi_module(y).squeeze(-1)
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/equinox/nn/_sequential.py:101, in Sequential.__call__(self, x, state, key)
#      99         x, state = layer(x, state=state, key=key)
#     100     else:
# --> 101         x = layer(x, key=key)
#     102 if state is sentinel:
#     103     return x
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/equinox/nn/_linear.py:92, in Linear.__call__(self, x, key)
#      90         raise ValueError("x must have scalar shape")
#      91     x = jnp.broadcast_to(x, (1,))
# ---> 92 x = self.weight @ x
#      93 if self.bias is not None:
#      94     x = x + self.bias
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/numpy/array_methods.py:271, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     269 args = (other, self) if swap else (self, other)
#     270 if isinstance(other, _accepted_binop_types):
# --> 271   return binary_op(*args)
#     272 # Note: don't use isinstance here, because we don't want to raise for
#     273 # subclasses, e.g. NamedTuple objects that may override operators.
#     274 if type(other) in _rejected_binop_types:
#
#     [... skipping hidden 12 frame]
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:3359, in matmul(a, b, precision, preferred_element_type)
#    3357 a = lax.squeeze(a, tuple(a_squeeze))
#    3358 b = lax.squeeze(b, tuple(b_squeeze))
# -> 3359 out = lax.dot_general(
#    3360   a, b, (((ndim(a) - 1,), (ndim(b) - 1 - b_is_mat,)), (a_batch, b_batch)),
#    3361   precision=precision, preferred_element_type=preferred_element_type)
#    3362 result = lax.transpose(out, perm)
#    3363 return lax_internal._convert_element_type(result, preferred_element_type, output_weak_type)
#
#     [... skipping hidden 7 frame]
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/lax/lax.py:2580, in _dot_general_shape_rule(lhs, rhs, dimension_numbers, precision, preferred_element_type)
#    2577 if not core.definitely_equal_shape(lhs_contracting_shape, rhs_contracting_shape):
#    2578   msg = ("dot_general requires contracting dimensions to have the same "
#    2579          "shape, got {} and {}.")
# -> 2580   raise TypeError(msg.format(lhs_contracting_shape, rhs_contracting_shape))
#    2582 return _dot_general_shape_computation(lhs.shape, rhs.shape, dimension_numbers)
#
# TypeError: dot_general requires contracting dimensions to have the same shape, got (3,) and (2,).
