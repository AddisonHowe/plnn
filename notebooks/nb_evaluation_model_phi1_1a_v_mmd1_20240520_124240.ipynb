# %% [markdown]
# # Trained Model Evaluation Notebook

# %%
import tqdm.notebook as tqdm
import numpy as np
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import jax.random as jrandom
import equinox as eqx
from IPython.display import HTML

from plnn.models import DeepPhiPLNN
from plnn.dataset import get_dataloaders
from plnn.data_generation.plnn_animator import PLNNSimulationAnimator
from plnn.io import load_model_from_directory, load_model_training_metadata
from plnn.loss_functions import select_loss_function

SEED = None
rng = np.random.default_rng(seed=SEED)

# %% [markdown]
# ### Model Loading

# %%
BASEDIR = "../data/trained_models"
MODEL_DIR = "model_phi1_1a_v_mmd1_20240520_124240"
MODEL_NAME = "model_phi1_1a_v_mmd1"

DATDIR = "../data/training_data/data_phi1_1a"

INDEX = 'best'
modeldir = f"../data/trained_models/{MODEL_DIR}"

# %%
datdir_train = f"{DATDIR}/training"
datdir_valid = f"{DATDIR}/validation"
datdir_test = f"{DATDIR}/testing"

nsims_train = np.genfromtxt(f"{datdir_train}/nsims.txt", dtype=int)
nsims_valid = np.genfromtxt(f"{datdir_valid}/nsims.txt", dtype=int)
nsims_test = np.genfromtxt(f"{datdir_test}/nsims.txt", dtype=int)

# %%
# Load the model
model, hyperparams, idx, model_name, model_fpath = load_model_from_directory(
    modeldir, 
    subdir="states",
    idx=INDEX,
    model_class=DeepPhiPLNN,
    dtype=jnp.float64,
)

# Load the argument dictionary and training run dictionary
logged_args, run_dict = load_model_training_metadata(
    modeldir
)

loss_train = run_dict['loss_hist_train']
loss_valid = run_dict['loss_hist_valid']
sigma_hist = run_dict['sigma_hist']
lr_hist = run_dict['learning_rate_hist']

print(f"Loading model `{model_name}` at epoch {idx} from file: {model_fpath}.")
# Out:
# Loading model `model_phi1_1a_v_mmd1` at epoch 1492 from file: ../data/trained_models/model_phi1_1a_v_mmd1_20240520_124240/states/model_phi1_1a_v_mmd1_1492.pth.

# %% [markdown]
# ### Training process metadata
# Before examining the inferred landscape, let's look at the training process metadata.

# %%
from plnn.pl import plot_training_loss_history, plot_validation_loss_history, \
    plot_loss_history, plot_sigma_history, plot_learning_rate_history

# %%
logplot = True
loss_method = logged_args['loss']
optimizer = logged_args['optimizer']

fig, axes = plt.subplots(3, 2, figsize=(12,8))

plot_loss_history(
    loss_train, loss_valid,
    log=logplot, 
    title=f"Loss History ({loss_method}, {optimizer})",
    ax=axes[0, 0],
)

plot_learning_rate_history(
    lr_hist, log=False,
    ax=axes[1, 0],
)

plot_sigma_history(
    sigma_hist, log=False,
    ax=axes[2, 0],
)

plot_training_loss_history(
    loss_train, 
    log=logplot, 
    title=f"Training Loss ({loss_method}, {optimizer})",
    ax=axes[0, 1],
    color='r', marker='.', linestyle='none',
)

plot_validation_loss_history(
    loss_valid, 
    log=logplot, 
    title=f"Validation Loss ({loss_method}, {optimizer})",
    ax=axes[1, 1],
    color='b',
)

plt.tight_layout()

# %% [markdown]
# ### Variance in loss
# Let's examine the noisyness of the training and validation loss in the plots above.

# %%
key = jrandom.PRNGKey(rng.integers(2**32))

# %%
k = 100
var_train_loss = np.var(loss_train[-k:])
var_valid_loss = np.var(loss_valid[-k:])
print(f"Training loss variance (last {k} epochs)  : {var_train_loss}")
print(f"Validation loss variance (last {k} epochs): {var_valid_loss}")
# Out:
# Training loss variance (last 100 epochs)  : 6.498005995799057e-09
# Validation loss variance (last 100 epochs): 4.483558888204674e-08

# %%
nepochs = len(loss_train)
start_epoch = 1000
k = 100
vtls = []
vvls = []
ranges = []
for i in range((nepochs - start_epoch) // k):
    n0, n1 = start_epoch + k*i, start_epoch + k*(i+1)
    tset = loss_train[n0:n1]
    vset = loss_valid[n0:n1]
    var_train_loss = np.var(tset)
    var_valid_loss = np.var(vset)
    vtls.append(var_train_loss)
    vvls.append(var_valid_loss)
    ranges.append(str(n0) + '-' + str(n1))

fig, ax = plt.subplots(1, 1)
ax.plot(vtls, label="Training")
ax.plot(vvls, label="Validation")
ax.set_xlabel("Epochs")
ax.set_ylabel("Avg loss variance")
ax.legend()
ax.set_xticks(range(len(ranges)), ranges, rotation=45);

# %%
_, _, test_loader, _, _, test_dset = get_dataloaders(
    datdir_train, datdir_valid, nsims_train, nsims_valid,
    return_datasets=True,
    include_test_data=True,
    datdir_test=datdir_test, nsims_test=nsims_test, shuffle_test=True,
    batch_size_test=20
)

# %%
@eqx.filter_jit
def compute_loss(model, x, y, loss_fn, key):
    t0, y0, t1, sigparams = x
    y_pred = model(t0, t1, y0, sigparams, key)
    return loss_fn(y_pred, y), y_pred

# %%
loss_function = select_loss_function('mmd')

# %%
ntrials = 10

avg_test_losses = np.zeros(ntrials)
pbar = tqdm.tqdm(total=len(test_loader))
for i in range(ntrials):
    test_losses = np.zeros(len(test_loader))
    pbar.set_description(f"i={i}/{ntrials}")
    for j, d in enumerate(test_loader):
        x, y = d
        key, subkey = jrandom.split(key, 2)
        loss, _ = compute_loss(model, x, y, loss_function, subkey)
        test_losses[j] = loss
        pbar.update()
    avg_test_losses[i] = np.sum(test_losses) / len(test_loader)
    pbar.refresh()
    pbar.reset()
pbar.close()

print(np.var(avg_test_losses))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 11
#       9 x, y = d
#      10 key, subkey = jrandom.split(key, 2)
# ---> 11 loss, _ = compute_loss(model, x, y, loss_function, subkey)
#      12 test_losses[j] = loss
#      13 pbar.update()
#
#     [... skipping hidden 4 frame]
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/pjit.py:257, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     255 @api_boundary
#     256 def cache_miss(*args, **kwargs):
# --> 257   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     258       fun, infer_params_fn, *args, **kwargs)
#     259   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     260   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/pjit.py:168, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     166   dispatch.check_arg(arg)
#     167 try:
# --> 168   out_flat = pjit_p.bind(*args_flat, **params)
#     169 except pxla.DeviceAssignmentMismatchError as e:
#     170   fails, = e.args
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/core.py:2740, in AxisPrimitive.bind(self, *args, **params)
#    2736 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2737                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2738 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2739              else axis_main.with_cur_sublevel())
# -> 2740 return self.bind_with_trace(top_trace, args, params)
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/core.py:935, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     934 def process_primitive(self, primitive, tracers, params):
# --> 935   return primitive.impl(*tracers, **params)
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/pjit.py:1245, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1242 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1243 has_explicit_sharding = _pjit_explicit_sharding(
#    1244     in_shardings, out_shardings, None, None)
# -> 1245 return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1246                     tree_util.dispatch_registry,
#    1247                     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/pjit.py:1229, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1228 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1229   out_flat, compiled = _pjit_call_impl_python(
#    1230       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1231       out_shardings=out_shardings, resource_env=resource_env,
#    1232       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1233       inline=inline)
#    1234   fastpath_data = _get_fastpath_data(
#    1235       compiled, tree_structure(out_flat), args, out_flat)
#    1236   return out_flat, fastpath_data
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/pjit.py:1162, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1156 global _most_recent_pjit_call_executable
#    1158 in_shardings = _resolve_in_shardings(
#    1159     args, in_shardings, out_shardings,
#    1160     resource_env.physical_mesh if resource_env is not None else None)
# -> 1162 compiled = _pjit_lower(
#    1163     jaxpr, in_shardings, out_shardings, resource_env,
#    1164     donated_invars, name, keep_unused, inline,
#    1165     lowering_parameters=mlir.LoweringParameters()).compile()
#    1166 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1167 # This check is expensive so only do it if enable_checks is on.
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2219, in MeshComputation.compile(self, compiler_options)
#    2217 def compile(self, compiler_options=None) -> MeshExecutable:
#    2218   if self._executable is None or compiler_options is not None:
# -> 2219     executable = UnloadedMeshExecutable.from_hlo(
#    2220         self._name, self._hlo, **self.compile_args,
#    2221         compiler_options=compiler_options)
#    2222     if compiler_options is None:
#    2223       self._executable = executable
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2659, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2656       mesh = i.mesh  # type: ignore
#    2657       break
# -> 2659 xla_executable, compile_options = _cached_compilation(
#    2660     hlo, name, mesh, spmd_lowering,
#    2661     tuple_args, auto_spmd_lowering, allow_prop_to_outputs,
#    2662     tuple(host_callbacks), backend, da, pmap_nreps,
#    2663     compiler_options_keys, compiler_options_values)
#    2665 if hasattr(backend, "compile_replicated"):
#    2666   semantics_in_shardings = SemanticallyEqualShardings(in_shardings)  # type: ignore
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2528, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, _allow_propagation_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_keys, compiler_options_values)
#    2523   return None, compile_options
#    2525 with dispatch.log_elapsed_time(
#    2526     "Finished XLA compilation of {fun_name} in {elapsed_time} sec",
#    2527     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2528   xla_executable = compiler.compile_or_get_cached(
#    2529       backend, computation, dev, compile_options, host_callbacks)
#    2530 return xla_executable, compile_options
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/compiler.py:296, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks)
#     292 use_compilation_cache = (compilation_cache.is_initialized() and
#     293                          backend.platform in supported_platforms)
#     295 if not use_compilation_cache:
# --> 296   return backend_compile(backend, computation, compile_options,
#     297                          host_callbacks)
#     299 compilation_cache.set_once_cache_used(
#     300     lambda: monitoring.record_event(
#     301         "/jax/compilation_cache/tasks_using_cache"))
#     302 monitoring.record_event('/jax/compilation_cache/compile_requests_use_cache')
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/Documents/Projects/plnn/env/lib/python3.9/site-packages/jax/_src/compiler.py:251, in backend_compile(backend, module, options, host_callbacks)
#     248 # we use a separate function call to ensure that XLA compilation appears
#     249 # separately in Python profiling results
#     250 if host_callbacks:
# --> 251   return backend.compile(built_c, compile_options=options,
#     252                          host_callbacks=host_callbacks)
#     253 # Some backends don't have `host_callbacks` option yet
#     254 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     255 # to take in `host_callbacks`
#     256 return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Comparison of true and inferred ensemble trajectories

# %%
_, _, test_loader, _, _, test_dset = get_dataloaders(
    datdir_train, datdir_valid, nsims_train, nsims_valid,
    return_datasets=True,
    include_test_data=True,
    datdir_test=datdir_test, nsims_test=nsims_test, shuffle_test=True,
    batch_size_test=1
)

# %%
key = jrandom.PRNGKey(123)

nsamps = 4
test_indices = [10, 78, 123, 132]

losses = np.zeros(nsamps)
x1obs_samples = []
x1sim_samples = []
iterloader = iter(test_loader)
for i in range(nsamps):
    inputs, x1obs = next(iterloader)
    inputs, x1obs = test_dset[test_indices[i]]
    t0, x0, t1, sigparams = inputs
    inputs = (jnp.array([v], dtype=jnp.float64) for v in inputs)
    x1obs = jnp.array([x1obs])
    key, subkey = jrandom.split(key, 2)
    model
    loss, x1sim = compute_loss(model, inputs, x1obs, loss_function, subkey)
    losses[i] = loss
    x1obs_samples.append(x1obs[0])
    x1sim_samples.append(x1sim[0])

# %%
fig, axes = plt.subplots(2, 2, figsize=(6,6))

for i in range(len(losses)):
    ax = axes.flatten()[i]
    ax.plot(
        x1obs_samples[i][:,0], x1obs_samples[i][:,1], 
        color='k', marker='.', linestyle='none',
        label="obs"
    )
    ax.plot(
        x1sim_samples[i][:,0], x1sim_samples[i][:,1], 
        color='r', marker='.', linestyle='none',
        label="sim",
        alpha=0.9
    )
    ax.legend()
    ax.set_xlabel("$x$")
    ax.set_ylabel("$y$")
    ax.set_title(f"Loss: {losses[i]:.4g}")

plt.tight_layout()
